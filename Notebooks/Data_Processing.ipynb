# %%
from Src.Data_Processing import (
    load_data,
    clean_data,
    get_categorical_columns,
    get_discrete_columns,
    encode_features,
    feature_engineering
)

# %% [markdown]
# Loading raw data

# %%
df = load_data("C:/Users/Admin/OneDrive/Documents/GitHub/Employee-Attrition-Analysis/Data/Raw/IBM HR Analysis.csv")

# %% [markdown]
# Cleaning data

# %%
df_clean = clean_data(df)

# %% [markdown]
# Identifying categorical and discrete numerical columns

# %%
categorical_cols = get_categorical_columns(df_clean)
discrete_cols = get_discrete_columns(df_clean)

print("Categorical columns:", categorical_cols)
print("                           ----------------------------------------------------------------------------------------")
print("Discrete numerical columns:", discrete_cols)
# Out:
# Categorical columns: ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
#                            ----------------------------------------------------------------------------------------
# Discrete numerical columns: ['Attrition', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# Encoding categorical features

# %%
df_encoded = encode_features(df_clean, categorical_cols)

# %% [markdown]
# Future engineering

# %%
df_final = feature_engineering(df_encoded)

# %% [markdown]
# Saving the final file

# %%
df_final.to_csv("../data/Cleaned/Cleaned_HR_Data.csv", index=False)
